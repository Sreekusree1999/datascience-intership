# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreekusree1999/datascience-intership/blob/main/TASK2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lets Grow More**
#
# **Task 2**
#
# Name : SREELEKSHMI B S
#
# **Data Science Internship**
#
# Image to Pencil Sketch with Python
#
# **Description Of Task** :We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.
# # New Section

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# **read the image**

# %%
img1 = cv2.imread("peak.jpg")
plt.figure(figsize=(8,8))
plt.imshow(img1)
plt.show()

# %%
rgbimage = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(rgbimage)
plt.show()

# %%
grayimage = cv2.cvtColor(rgbimage, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(grayimage,cmap='gray')
plt.show()

# %% [markdown]
#  **Converting the gray scale image in to a inverted image**

# %%
invtgrayimage =255 - grayimage
plt.figure(figsize=(8,8))
plt.imshow(invtgrayimage,cmap='gray')
plt.show()

# %% [markdown]
# **Bluring the inverted grayscale image using Gaussian Blur**

# %%
blurimage = cv2.GaussianBlur(invtgrayimage, (21,21), 0)
plt.figure(figsize=(8,8))
plt.imshow(blurimage,cmap='gray')
plt.show()

# %% [markdown]
# **Now inverting the blurred image**

# %%
invtblurimage = 255 - blurimage
plt.figure(figsize=(8,8))
plt.imshow(invtblurimage,cmap='gray')
plt.show()

# %% [markdown]
# **Now for the final touch divide the grayscale image with inverted blurred image**

# %%
sketch1 = cv2.divide(grayimage, invtblurimage, scale=256.0)
plt.figure(figsize=(8,8))
plt.imshow(rgbimage)
plt.figure(figsize=(8,8))
plt.imshow(sketch1,cmap='gray')
plt.show()
